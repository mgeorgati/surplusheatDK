# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../data/processed/comparison_bysector.xlsx', sheet_name='used')

# %%
df
# Out:
#                             Shares  Current utilisation  High temperature  \
# 0  Agriculture, Forestry & Fishing             0.022243          0.002156
# 1        Energy, Mining & Services             1.826852          0.011031
# 2                  Food & Beverage             0.048288          0.554870
# 3         Manufacturing & Industry             2.088182          0.511484
# 4                   Retail & Trade             0.003158          0.153890
# 5                          Unknown             0.000000          0.247554
#
#    Medium temperature  Low temperature
# 0            0.000202         0.003515
# 1            0.006009         0.046380
# 2            0.239816         2.272403
# 3            0.637874         1.126317
# 4            0.058523         2.329453
# 5            0.171362         0.977326

# %%
# Set figure size and style
# Define custom colors for each category
colors = {
    "High temperature": "#8c6b72",  # Blue
    "Medium temperature": "#918ab5",  # Orange
    "Low temperature": "#c7c1e8",  # Green
    "Current utilisation": "#878f9c"  # Red
}

# Set figure size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Plot stacked bar chart with assigned colors
df.set_index("Shares").plot(
    kind="bar", stacked=True, color=[colors[col] for col in df.columns[1:]], figsize=(10, 6)
)

# Labels and title
plt.xlabel("Sectors", fontsize=12)
plt.ylabel("Share of contribution (%)", fontsize=12)
#plt.title("Distribution of Heat Utilization Across Sectors", fontsize=14)
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()

# Show plot
plt.show()
